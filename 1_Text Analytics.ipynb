# %% [markdown]
# ### Section 1: Text Analytics / Use Pre-trained Model
#
# #### Topic covered:
# #### 1. Common Funtions
# - Package Install
# - Find a word's position in an article
# - Find other words that appear together with your target words
# - Determine the location of a word in the text
# - Generate random words
# - Find distinct words and calculate the lexical level
# - Frequent distributions
# - Review common functions
# - Tokenize (words/sentences)
# - Stop words
# - Labeling words
#
# #### 2. Sentiment Score
# - Negative
# - Neutral
# - Positive
#
# Reference: https://www.nltk.org/book/

# %%
import nltk

# %%
nltk.download()

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# ### Find a word's position in the text

# %%
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %% [markdown]
# ### What other words appear in a similar range of contexts?

# %%
text2.similar("happy")
# Out:
# much that impossible long soon well and so before young far given she
# sure rich civil sorry glad they good

# %%
print(text2)
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %% [markdown]
# ### Determine the location of a word in the text

# %%
text4.dispersion_plot(["happy","citizens", "democracy", "freedom", "duties", "America"])

# %% [markdown]
# ### Count unique words and sort it

# %%
len(text3)
# Out:
# 44764

# %%
sorted(set(text3))
# Out:
# ['!',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',)',
#  '.',
#  '.)',
#  ':',
#  ';',
#  ';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech',
#  'Abr',
#  'Abrah',
#  'Abraham',
#  'Abram',
#  'Accad',
#  'Achbor',
#  'Adah',
#  'Adam',
#  'Adbeel',
#  'Admah',
#  'Adullamite',
#  'After',
#  'Aholibamah',
#  'Ahuzzath',
#  'Ajah',
#  'Akan',
#  'All',
#  'Allonbachuth',
#  'Almighty',
#  'Almodad',
#  'Also',
#  'Alvah',
#  'Alvan',
#  'Am',
#  'Amal',
#  'Amalek',
#  'Amalekites',
#  'Ammon',
#  'Amorite',
#  'Amorites',
#  'Amraphel',
#  'An',
#  'Anah',
#  'Anamim',
#  'And',
#  'Aner',
#  'Angel',
#  'Appoint',
#  'Aram',
#  'Aran',
#  'Ararat',
#  'Arbah',
#  'Ard',
#  'Are',
#  'Areli',
#  'Arioch',
#  'Arise',
#  'Arkite',
#  'Arodi',
#  'Arphaxad',
#  'Art',
#  'Arvadite',
#  'As',
#  'Asenath',
#  'Ashbel',
#  'Asher',
#  'Ashkenaz',
#  'Ashteroth',
#  'Ask',
#  'Asshur',
#  'Asshurim',
#  'Assyr',
#  'Assyria',
# ...

# %%
# lexical recource
len(set(text3))
# Out:
# 2789

# %%
saying = ['After', 'all', 'is', 'said', 'and', 'done', 'more', 'is', 'said', 'than', 'done']

# %%
tokens = set(saying)
tokens = sorted(tokens)
tokens[-2:]
tokens
# Out:
# ['After', 'all', 'and', 'done', 'is', 'more', 'said', 'than']

# %% [markdown]
# ### Frequent distributions

# %%
fdist1 = FreqDist(text1)

# %%
fdist1.most_common(50)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624)]

# %% [markdown]
# ### Tokenize
# Reference: https://pythonprogramming.net/part-of-speech-tagging-nltk-tutorial/

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

EXAMPLE_TEXT = "Hello Mr. Smith, how are you doing today? The weather is great, and Python is awesome. The sky is pinkish-blue. You shouldn't eat cardboard."

print(sent_tokenize(EXAMPLE_TEXT))
print(word_tokenize(EXAMPLE_TEXT))
# Out:
# ['Hello Mr. Smith, how are you doing today?', 'The weather is great, and Python is awesome.', 'The sky is pinkish-blue.', "You shouldn't eat cardboard."]
# ['Hello', 'Mr.', 'Smith', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'Python', 'is', 'awesome', '.', 'The', 'sky', 'is', 'pinkish-blue', '.', 'You', 'should', "n't", 'eat', 'cardboard', '.']

# %% [markdown]
# ### Filter out stop words (e.g., a, an, the etc.)
# Reference: https://pythonprogramming.net/part-of-speech-tagging-nltk-tutorial/

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
stop_words = set(stopwords.words('english'))
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
# ...

# %%
example_sent = "This is a sample sentence, showing off the stop words filtration."

stop_words = set(stopwords.words('english'))

word_tokens = word_tokenize(example_sent)


filtered_sentence = []

for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)

print(word_tokens)
print(filtered_sentence)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']
# ['This', 'sample', 'sentence', ',', 'showing', 'stop', 'words', 'filtration', '.']

# %% [markdown]
# ### The idea of stemming is a sort of normalizing method. Many variations of words carry the same meaning, other than when tense is involved.
# Reference: https://pythonprogramming.net/part-of-speech-tagging-nltk-tutorial/

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()

# %%
example_words = ["python","pythoner","pythoning","pythoned","pythonly"]
for w in example_words:
    print(ps.stem(w))
# Out:
# python
# python
# python
# python
# pythonli

# %% [markdown]
# ### Sentiment Analysis
#
# Reference: https://pythonprogramming.net/part-of-speech-tagging-nltk-tutorial/

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import sent_tokenize, word_tokenize
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\duant\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores("Wow, NLTK is really powerful!")
# Out:
# {'neg': 0.0, 'neu': 0.295, 'pos': 0.705, 'compound': 0.8012}

# %%
review = '''
Top notch hotel no matter where in the world you visit their properties. Excellent food, service, Gold members get complimentary upgrades. I call it superlative, but only if u can afford it, is it worth the premium.
'''

# %%
tokened_review=sent_tokenize(review)

# %%
for i in tokened_review:
    print(i)
    sia.polarity_scores(i)
    print(sia.polarity_scores(i))
# Out:
# Top notch hotel no matter where in the world you visit their properties.
# {'neg': 0.146, 'neu': 0.662, 'pos': 0.192, 'compound': -0.0772}
# Excellent food, service, Gold members get complimentary upgrades.
# {'neg': 0.0, 'neu': 0.476, 'pos': 0.524, 'compound': 0.765}
# I call it superlative, but only if u can afford it, is it worth the premium.
# {'neg': 0.0, 'neu': 0.847, 'pos': 0.153, 'compound': 0.3291}

# %%
review2 = '''Loved it everything was perfect I would 100 percent recommend this place to anyone who is visiting New York
'''

# %%
tokened_review2=sent_tokenize(review2)

# %%
for i in tokened_review2:
    print(i)
    sia.polarity_scores(i)
    print(sia.polarity_scores(i))
# Out:
# Loved it everything was perfect I would 100 percent recommend this place to anyone who is visiting New York
# {'neg': 0.0, 'neu': 0.598, 'pos': 0.402, 'compound': 0.8779}

# %% [markdown]
# ### Labeling words in a sentence as nouns, adjectives, verbs
#
# Reference: https://pythonprogramming.net/part-of-speech-tagging-nltk-tutorial/

# %% [markdown]
# POS tag list:
#
# - CC	coordinating conjunction
# - CD	cardinal digit
# - DT	determiner
# - EX	existential there (like: "there is" ... think of it like "there exists")
# - FW	foreign word
# - IN	preposition/subordinating conjunction
# - JJ	adjective	'big'
# - JJR	adjective, comparative	'bigger'
# - JJS	adjective, superlative	'biggest'
# - LS	list marker	1)
# - MD	modal	could, will
# - NN	noun, singular 'desk'
# - NNS	noun plural	'desks'
# - NNP	proper noun, singular	'Harrison'
# - NNPS	proper noun, plural	'Americans'
# - PDT	predeterminer	'all the kids'
# - POS	possessive ending	parent\'s
# - PRP	personal pronoun	I, he, she
# - PRP	possessive pronoun	my, his, hers
# - RB	adverb	very, silently,
# - RBR	adverb, comparative	better
# - RBS	adverb, superlative	best
# - RP	particle	give up
# - TO	to	go 'to' the store.
# - UH	interjection	errrrrrrrm
# - VB	verb, base form	take
# - VBD	verb, past tense	took
# - VBG	verb, gerund/present participle	taking
# - VBN	verb, past participle	taken
# - VBP	verb, sing. present, non-3d	take
# - VBZ	verb, 3rd person sing. present	takes
# - WDT	wh-determiner	which
# - WP	wh-pronoun	who, what
# - WP	possessive wh-pronoun	whose
# - WRB	wh-abverb	where, when

# %%
import nltk
from nltk.corpus import state_union
from nltk.tokenize import PunktSentenceTokenizer

# %%
sample_text = state_union.raw("2006-GWBush.txt")

# %%
sample_text

# %%
custom_sent_tokenizer = PunktSentenceTokenizer(sample_text)
tokenized = custom_sent_tokenizer.tokenize(sample_text)

# %%
tokenized[:2]

# %%
for i in tokenized[:2]:
        words = nltk.word_tokenize(i)
        tagged = nltk.pos_tag(words)
        print(tagged)

# %% [markdown]
# ### Functions

# %% [markdown]
# Example	Description
# - fdist = FreqDist(samples)	create a frequency distribution containing the given samples
# - fdist[sample] += 1	increment the count for this sample
# - fdist['monstrous']	count of the number of times a given sample occurred
# - fdist.freq('monstrous')	frequency of a given sample
# - fdist.N()	total number of samples
# - fdist.most_common(n)	the n most common samples and their frequencies
# - for sample in fdist:	iterate over the samples
# - fdist.max()	sample with the greatest count
# - fdist.tabulate()	tabulate the frequency distribution
# - fdist.plot()	graphical plot of the frequency distribution
# - fdist.plot(cumulative=True)	cumulative plot of the frequency distribution
# - fdist1 |= fdist2	update fdist1 with counts from fdist2
# - fdist1 < fdist2	test if samples in fdist1 occur less frequently than in fdist2

# %%
samples = ['a','b','c','monstrous','d','monstrous']
fdist1 = FreqDist(samples) 
samples2 = ['apple','banana','cindy','monstrous','dog','monstrous']
fdist2 = FreqDist(samples2)

# %%
fdist1['monstrous'] += 1 
print(samples)

# %%
fdist1['monstrous']

# %%
fdist1.freq('monstrous')

# %%
fdist1.N()

# %%
fdist1.most_common(3)

# %%
fdist1.max()

# %%
fdist1.tabulate()

# %%
fdist1.plot();

# %%
fdist1 |= fdist2

# %%
fdist1

# %%
fdist1 < fdist2

# %% [markdown]
# ### Generating some random text in the various styles we have just seen

# %%
text3.generate()
